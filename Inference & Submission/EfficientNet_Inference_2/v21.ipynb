# %%
import warnings
warnings.simplefilter(action='ignore')

import argparse
import os,cv2
import random,numpy,pandas
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
import argparse
import os
import random,numpy
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import torchvision.utils as vutils
from torchvision.models.feature_extraction import create_feature_extractor
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
seed = 999
print("Random Seed: ", seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)
# Out:
# Random Seed:  999

# %%
ngpu=1
ngf,nc = 3,3
ndf = 64

transform = transforms.Compose([
    transforms.Resize((100,100)),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %%
class EffnetModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        effnet = torchvision.models.efficientnet_v2_m(weights=torchvision.models.efficientnet.EfficientNet_V2_M_Weights.DEFAULT)
        self.model = create_feature_extractor(effnet, ['flatten'])
        self.nn_fracture = torch.nn.Sequential(
            torch.nn.Linear(1280, 1)
        )
    def forward(self, x):
        x = self.model(x)['flatten']
        x = self.nn_fracture(x)
        return x

# %%
EFF_NET = EffnetModel().float()
EFF_NET= nn.DataParallel(EFF_NET).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_m-dc08266a.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_m-dc08266a.pth
# 100%|██████████| 208M/208M [00:01<00:00, 207MB/s]

# %%
fsc_submission=numpy.array(pandas.read_csv("/kaggle/input/ai-vs-human-generated-dataset/test.csv")['id'])

# %%
sub = ([0]*len(fsc_submission))
file_ = ['/kaggle/input/detect-ai-vs-human-generated-images-mode-2/0.00011639301374088973 49.pth']

EFF_NET.load_state_dict(torch.load(f"{file_[0]}",
                                   weights_only=False,
                                   map_location=torch.device('cpu')))

for i in range(0, len(fsc_submission), 10):
    img = torch.Tensor(numpy.array([transform(Image.open(f'/kaggle/input/d/mafiosoquasar/detect-ai-vs-human-generated-images/test/{fsc_submission[s].split("/")[1]}')).reshape((3, 100, 100)) for s in range(i, i+10)])).float().to(device)    
    z_arr = EFF_NET(img).sigmoid().cpu().detach().numpy().reshape(-1)
    for j,n in zip(z_arr, range(i, i+10)):
        sub[n] = j

# %%
submission=pandas.DataFrame({'id' : fsc_submission, 
                             'label' : numpy.array(sub)})

for i in range(len(submission['label'])):
    if submission.iloc[[i]]['label'].to_numpy()[0]>0.5:
        submission.loc[i,'label']=1
    else:
        submission.loc[i,'label']=0
        
pandas.DataFrame(submission).to_csv(f"submission.csv", index=False)
pandas.DataFrame(submission)
# Out:
#                                                      id  label
# 0     test_data_v2/1a2d9fd3e21b4266aea1f66b30aed157.jpg    1.0
# 1     test_data_v2/ab5df8f441fe4fbf9dc9c6baae699dc7.jpg    0.0
# 2     test_data_v2/eb364dd2dfe34feda0e52466b7ce7956.jpg    1.0
# 3     test_data_v2/f76c2580e9644d85a741a42c6f6b39c0.jpg    1.0
# 4     test_data_v2/a16495c578b7494683805484ca27cf9f.jpg    1.0
# ...                                                 ...    ...
# 5535  test_data_v2/483412064ff74d9d9472d606b65976d9.jpg    0.0
# 5536  test_data_v2/c0b49ba4081a4197b422dac7c15aea7f.jpg    1.0
# 5537  test_data_v2/01454aaedec140c0a3ca1f48028c41cf.jpg    1.0
# 5538  test_data_v2/e9adfea8b67e4791968c4c2bdd8ec343.jpg    0.0
# 5539  test_data_v2/ba8f4198e8d74d3394fa56c56af23442.jpg    0.0
#
# [5540 rows x 2 columns]
