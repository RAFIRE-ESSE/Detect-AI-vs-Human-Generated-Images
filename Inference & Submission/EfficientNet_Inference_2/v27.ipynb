# %%
import warnings
warnings.simplefilter(action='ignore')

import argparse
import os,cv2
import random,numpy,pandas
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
import argparse
import os
import random,numpy
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import torchvision.utils as vutils
from torchvision.models.feature_extraction import create_feature_extractor
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
seed = 999
print("Random Seed: ", seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)
# Out:
# Random Seed:  999

# %%
ngpu=1
ngf,nc = 3,3
ndf = 64

transform = transforms.Compose([
    transforms.Resize((450,450)),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %%
class EffnetModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        effnet = torchvision.models.efficientnet_v2_m(weights=torchvision.models.efficientnet.EfficientNet_V2_M_Weights.DEFAULT)
        self.model = create_feature_extractor(effnet, ['flatten'])
        self.nn_fracture = torch.nn.Sequential(
            torch.nn.Linear(1280, 1)
        )
    def forward(self, x):
        x = self.model(x)['flatten']
        x = self.nn_fracture(x)
        return x

# %%
EFF_NET = EffnetModel().float()
EFF_NET= nn.DataParallel(EFF_NET).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_m-dc08266a.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_m-dc08266a.pth
# 100%|██████████| 208M/208M [00:01<00:00, 115MB/s]

# %%
fsc_submission=pandas.read_csv("/kaggle/input/ai-vs-human-generated-dataset/test.csv")['id']

# %%
sub = ([0]*len(fsc_submission))
file_ = ['4.161920151091181e-05 5.pth']

EFF_NET.load_state_dict(torch.load(f"/kaggle/input/detect-ai-vs-human-generated-images-mode-2/{file_[0]}",
                                   weights_only=False, 
                                   map_location=torch.device('cpu')))    

for i,j in zip(fsc_submission,range(len(fsc_submission))):
    #print(i.split("/")[1])
    img = transform(Image.open(f'/kaggle/input/detect-ai-vs-human-generated-images-model/test/{i.split("/")[1]}')).reshape((1, 3, 450, 450)).float().to(device)    
    sub[j] += EFF_NET(img).sigmoid().cpu().detach().numpy()[0][0]

# %%
submission=pandas.DataFrame({'id' : fsc_submission, 
                             'label' : numpy.array(sub)})
pandas.DataFrame(submission).to_csv(f"submission.csv", index=False)
pandas.DataFrame(submission)
# Out:
#                                                    id     label
# 0      test_data/e25323c62af644fba97afb846261b05b.jpg  0.000035
# 1      test_data/63c7596c97d74c1cb6323db1b7380d5e.jpg  0.999941
# 2      test_data/0a5eb7abb22b439580836e22d89e8ca1.jpg  0.999953
# 3      test_data/371eddabfc1349a08534ce2292c4c4d3.jpg  0.928025
# 4      test_data/7280ea6acaa14a52b7218ae36305b218.jpg  0.000013
# ...                                               ...       ...
# 19981  test_data/796cac2f053b4fc1866a81921e1fe3fa.jpg  0.000652
# 19982  test_data/789ee13ba9f84e138913e0a9f7d5d93b.jpg  0.000277
# 19983  test_data/a77a1a10cac34f98a085e51997227dbd.jpg  0.000013
# 19984  test_data/23641fee71b142b288958f4cdd91d001.jpg  0.002639
# 19985  test_data/56d90ca3f14a44a9b4fde455eeaa19c3.jpg  0.999955
#
# [19986 rows x 2 columns]
